# %% [markdown]
# ####Import required libraries and set spark context

# %%
import pyspark
from pyspark.sql import SparkSession
from pyspark.sql.types import StructType,StructField, StringType, IntegerType 
from pyspark.sql.types import ArrayType, DoubleType, BooleanType
from pyspark.sql.functions import col,array_contains

# %%
spark = SparkSession.builder.appName('Read CSV').getOrCreate()

# %% [markdown]
# ####Import data set of customer into dataframe

# %%
df_customer=sqlContext.sql("SELECT * FROM arl_feature_store.customer_data_credit_debit_src")

# %% [markdown]
# ####Display data set of the customer

# %%
display(df_customer)
df_customer.printSchema()
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>age</th><th>location</th><th>gender</th><th>transacted_amount</th><th>transacted_date</th><th>credit/debit</th><th>zip</th><th>ssn</th><th>transacted_at</th><th>fname</th><th>lname</th><th>email</th></tr></thead><tbody><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>12832</td><td>2022-09-19</td><td>1</td><td>419154</td><td>8887475444</td><td>Pay with Tap</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST235925</td><td>38</td><td>MA</td><td>F</td><td>48233</td><td>2022-10-23</td><td>1</td><td>199520</td><td>7323084732</td><td>Pay with Tap</td><td>Margaret</td><td>Vasquez</td><td>margaret.vasquez@day.com</td></tr><tr><td>CUST768307</td><td>41</td><td>WA</td><td>M</td><td>46000</td><td>2023-02-07</td><td>1</td><td>522663</td><td>1425823974</td><td>Zelle QR Code</td><td>Derek</td><td>Rivera</td><td>derek.rivera@greene.com</td></tr><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>54991</td><td>2023-01-22</td><td>1</td><td>236362</td><td>8475385450</td><td>Help Center</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>71251</td><td>2022-09-21</td><td>1</td><td>419154</td><td>8887475444</td><td>Food Street</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST235925</td><td>38</td><td>MA</td><td>F</td><td>35028</td><td>2023-01-25</td><td>1</td><td>199520</td><td>7323084732</td><td>Fuel</td><td>Margaret</td><td>Vasquez</td><td>margaret.vasquez@day.com</td></tr><tr><td>CUST768307</td><td>41</td><td>WA</td><td>M</td><td>22869</td><td>2023-02-13</td><td>1</td><td>522663</td><td>1425823974</td><td>Cloths</td><td>Derek</td><td>Rivera</td><td>derek.rivera@greene.com</td></tr><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>49695</td><td>2023-03-27</td><td>1</td><td>236362</td><td>8475385450</td><td>Pay with Tap</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>73480</td><td>2022-11-03</td><td>1</td><td>419154</td><td>8887475444</td><td>Pay with Tap</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST235925</td><td>38</td><td>MA</td><td>F</td><td>13099</td><td>2022-07-16</td><td>1</td><td>199520</td><td>7323084732</td><td>Zelle QR Code</td><td>Margaret</td><td>Vasquez</td><td>margaret.vasquez@day.com</td></tr><tr><td>CUST768307</td><td>41</td><td>WA</td><td>M</td><td>5283</td><td>2022-09-03</td><td>1</td><td>522663</td><td>1425823974</td><td>Help Center</td><td>Derek</td><td>Rivera</td><td>derek.rivera@greene.com</td></tr><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>84655</td><td>2023-02-17</td><td>1</td><td>236362</td><td>8475385450</td><td>Food Street</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>16434</td><td>2022-08-05</td><td>1</td><td>419154</td><td>8887475444</td><td>Fuel</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST235925</td><td>38</td><td>MA</td><td>F</td><td>86030</td><td>2023-03-03</td><td>1</td><td>199520</td><td>7323084732</td><td>Cloths</td><td>Margaret</td><td>Vasquez</td><td>margaret.vasquez@day.com</td></tr><tr><td>CUST768307</td><td>41</td><td>WA</td><td>M</td><td>27467</td><td>2022-07-27</td><td>1</td><td>522663</td><td>1425823974</td><td>Pay with Tap</td><td>Derek</td><td>Rivera</td><td>derek.rivera@greene.com</td></tr><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>14415</td><td>2022-10-07</td><td>1</td><td>236362</td><td>8475385450</td><td>Pay with Tap</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>57323</td><td>2022-10-03</td><td>1</td><td>419154</td><td>8887475444</td><td>Zelle ...
# root
#  |-- customer_id: string (nullable = true)
#  |-- age: long (nullable = true)
#  |-- location: string (nullable = true)
#  |-- gender: string (nullable = true)
#  |-- transacted_amount: long (nullable = true)
#  |-- transacted_date: date (nullable = true)
#  |-- credit/debit: long (nullable = true)
#  |-- zip: long (nullable = true)
#  |-- ssn: long (nullable = true)
#  |-- transacted_at: string (nullable = true)
#  |-- fname: string (nullable = true)
#  |-- lname: string (nullable = true)
#  |-- email: string (nullable = true)

# %% [markdown]
# ####Write function to filter data based on date range provided and to filter by credit transaction if credit/debit=1 then credit credit/debit=0 then debit. In this notebook we are concentrating on credit transaction.

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import FloatType, IntegerType, StringType
from pytz import timezone

def filter_df_by_date_credit(df, ts_column, credit_debit, start_date, end_date):
    df = df.filter(col(credit_debit)== 1)
    if ts_column and start_date:
        df = df.filter(col(ts_column) <= start_date)
    if ts_column and end_date:
        df = df.filter(col(ts_column) >= end_date)
    return df

# %% [markdown]
# ####Data preparation to pass parameters for 7 days, 30 days and 60 days

# %%
from datetime import *
start_date=date.today()
print(start_date)
end_date_7_days=start_date-timedelta(days=7)
print(end_date_7_days)
end_date_30_days=start_date-timedelta(days=30)
print(end_date_30_days)
end_date_60_days=start_date-timedelta(days=60)
print(end_date_60_days)
# Out:
# 2023-02-01
# 2023-01-25
# 2023-01-02
# 2022-12-03

# %% [markdown]
# ####Check if data filtering function is working properly

# %%
from datetime import datetime
filtered_data= filter_df_by_date_credit(
    df_customer, ts_column="transacted_date", credit_debit="credit/debit", start_date=start_date, end_date=end_date_60_days)
display(filtered_data)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>customer_id</th><th>age</th><th>location</th><th>gender</th><th>transacted_amount</th><th>transacted_date</th><th>credit/debit</th><th>zip</th><th>ssn</th><th>transacted_at</th><th>fname</th><th>lname</th><th>email</th></tr></thead><tbody><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>54991</td><td>2023-01-22</td><td>1</td><td>236362</td><td>8475385450</td><td>Help Center</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST235925</td><td>38</td><td>MA</td><td>F</td><td>35028</td><td>2023-01-25</td><td>1</td><td>199520</td><td>7323084732</td><td>Fuel</td><td>Margaret</td><td>Vasquez</td><td>margaret.vasquez@day.com</td></tr><tr><td>CUST854589</td><td>36</td><td>MN</td><td>M</td><td>14554</td><td>2023-01-16</td><td>1</td><td>419154</td><td>8887475444</td><td>Cloths</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST235925</td><td>36</td><td>MN</td><td>M</td><td>87181</td><td>2022-12-25</td><td>1</td><td>419154</td><td>8887475444</td><td>Help Center</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr><tr><td>CUST854589</td><td>18</td><td>OK</td><td>F</td><td>21406</td><td>2023-01-25</td><td>1</td><td>236362</td><td>8475385450</td><td>Pay with Tap</td><td>Sarah</td><td>Campbell</td><td>sarah.campbell@reese.com</td></tr><tr><td>CUST301488</td><td>36</td><td>MN</td><td>M</td><td>54401</td><td>2022-12-22</td><td>1</td><td>419154</td><td>8887475444</td><td>Zelle QR Code</td><td>James</td><td>Rogers</td><td>james.rogers@olson.com</td></tr></tbody></table></div>

# %% [markdown]
# #### Build feature to get sum of amount transacted by each customer over given period of time(input)

# %%
def transacted_amt_by_customer(df, ts_column, credit_debit, start_date, end_date):

    """
    Computes the total amount transacted by customer over the time frame passed as input parameter
    """
    df = filter_df_by_date_credit(df, ts_column, credit_debit, start_date, end_date)
 
    trans_amt_feature = (
        df.groupBy(
            "customer_id") 
        .agg(
            sum("transacted_amount").alias("amount_transacted_by_cust_over_given_period"),
            count("transacted_date").alias("total_no_of_transactions"),
        )
        .select(
            col("customer_id").alias("cust_id"),
            col("amount_transacted_by_cust_over_given_period").cast(FloatType()),
            col("total_no_of_transactions").cast(IntegerType())
        )
    )
    trans_amt_feature=trans_amt_feature.withColumn("todays_date",current_date())

    return trans_amt_feature

# %% [markdown]
# ####Run the code to realise the feature and store it in data frame for 7, 30 and 60 days

# %%
from datetime import datetime
transacted_amt_feature_credit_7_days = transacted_amt_by_customer(
    df_customer, ts_column="transacted_date", credit_debit="credit/debit", start_date=start_date, end_date=end_date_7_days)

transacted_amt_feature_credit_30_days = transacted_amt_by_customer(
    df_customer, ts_column="transacted_date", credit_debit="credit/debit", start_date=start_date, end_date=end_date_30_days)

transacted_amt_feature_credit_60_days = transacted_amt_by_customer(
    df_customer, ts_column="transacted_date", credit_debit="credit/debit", start_date=start_date, end_date=end_date_60_days)

# %% [markdown]
# ####Rename the dataframe columns to give meaningful column names.

# %%
transacted_amt_feature_credit_7_days=transacted_amt_feature_credit_7_days.withColumnRenamed("amount_transacted_by_cust_over_given_period","amount_transacted_by_cust_over_7_days_credit").withColumnRenamed("total_no_of_transactions","total_no_of_credit_transactions_7_days")

transacted_amt_feature_credit_30_days=transacted_amt_feature_credit_30_days.withColumnRenamed("amount_transacted_by_cust_over_given_period","amount_transacted_by_cust_over_30_days_credit").withColumnRenamed("total_no_of_transactions","total_no_of_credit_transactions_30_days")

transacted_amt_feature_credit_60_days=transacted_amt_feature_credit_60_days.withColumnRenamed("amount_transacted_by_cust_over_given_period","amount_transacted_by_cust_over_60_days_credit").withColumnRenamed("total_no_of_transactions","total_no_of_credit_transactions_60_days")

# %% [markdown]
# ####Results of the features for 7,30 and 60 days.

# %%
display(transacted_amt_feature_credit_7_days)
display(transacted_amt_feature_credit_30_days)
display(transacted_amt_feature_credit_60_days)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>amount_transacted_by_cust_over_7_days_credit</th><th>total_no_of_credit_transactions_7_days</th><th>todays_date</th></tr></thead><tbody><tr><td>CUST235925</td><td>35028.0</td><td>1</td><td>2023-02-01</td></tr><tr><td>CUST854589</td><td>21406.0</td><td>1</td><td>2023-02-01</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>amount_transacted_by_cust_over_30_days_credit</th><th>total_no_of_credit_transactions_30_days</th><th>todays_date</th></tr></thead><tbody><tr><td>CUST235925</td><td>35028.0</td><td>1</td><td>2023-02-01</td></tr><tr><td>CUST854589</td><td>90951.0</td><td>3</td><td>2023-02-01</td></tr></tbody></table></div>
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>cust_id</th><th>amount_transacted_by_cust_over_60_days_credit</th><th>total_no_of_credit_transactions_60_days</th><th>todays_date</th></tr></thead><tbody><tr><td>CUST235925</td><td>122209.0</td><td>2</td><td>2023-02-01</td></tr><tr><td>CUST301488</td><td>54401.0</td><td>1</td><td>2023-02-01</td></tr><tr><td>CUST854589</td><td>90951.0</td><td>3</td><td>2023-02-01</td></tr></tbody></table></div>

# %% [markdown]
# ####Use Feature Store library to create new feature table

# %%
# %sql 
CREATE DATABASE IF NOT EXISTS arl_feature_store;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr></tr></thead><tbody></tbody></table></div>

# %% [markdown]
# ####Install feature store

# %%
pip install databricks-feature-store
# Out:
# Python interpreter will be restarted.
# Requirement already satisfied: databricks-feature-store in /databricks/python3/lib/python3.9/site-packages (0.9.0)
# Requirement already satisfied: mlflow-skinny<3,>=1.28.0 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (2.1.1)
# Requirement already satisfied: azure-cosmos<5,>=4.2.0 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (4.2.0)
# Requirement already satisfied: protobuf<5,>=3.12.0 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (3.19.4)
# Requirement already satisfied: boto3<2,>=1.16.7 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (1.21.32)
# Requirement already satisfied: pyspark<4,>=3.1.2 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b1878b62-c8b4-41f4-8568-c03a661bb9e4/lib/python3.9/site-packages (from databricks-feature-store) (3.3.1)
# Requirement already satisfied: flask<3,>=1.1.2 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (1.1.2)
# Requirement already satisfied: dbl-tempo<1,>=0.1.2 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (0.1.12)
# Requirement already satisfied: pyyaml<7,>=6 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (6.0)
# Requirement already satisfied: numpy<2,>=1.19.2 in /databricks/python3/lib/python3.9/site-packages (from databricks-feature-store) (1.21.5)
# Requirement already satisfied: azure-core<2.0.0,>=1.0.0 in /databricks/python3/lib/python3.9/site-packages (from azure-cosmos<5,>=4.2.0->databricks-feature-store) (1.26.1)
# Requirement already satisfied: six>=1.6 in /databricks/python3/lib/python3.9/site-packages (from azure-cosmos<5,>=4.2.0->databricks-feature-store) (1.16.0)
# Requirement already satisfied: requests>=2.18.4 in /databricks/python3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.0.0->azure-cosmos<5,>=4.2.0->databricks-feature-store) (2.27.1)
# Requirement already satisfied: typing-extensions>=4.0.1 in /databricks/python3/lib/python3.9/site-packages (from azure-core<2.0.0,>=1.0.0->azure-cosmos<5,>=4.2.0->databricks-feature-store) (4.1.1)
# Requirement already satisfied: botocore<1.25.0,>=1.24.32 in /databricks/python3/lib/python3.9/site-packages (from boto3<2,>=1.16.7->databricks-feature-store) (1.24.32)
# Requirement already satisfied: s3transfer<0.6.0,>=0.5.0 in /databricks/python3/lib/python3.9/site-packages (from boto3<2,>=1.16.7->databricks-feature-store) (0.5.0)
# Requirement already satisfied: jmespath<2.0.0,>=0.7.1 in /databricks/python3/lib/python3.9/site-packages (from boto3<2,>=1.16.7->databricks-feature-store) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /databricks/python3/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.32->boto3<2,>=1.16.7->databricks-feature-store) (2.8.2)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /databricks/python3/lib/python3.9/site-packages (from botocore<1.25.0,>=1.24.32->boto3<2,>=1.16.7->databricks-feature-store) (1.26.9)
# Requirement already satisfied: pandas in /databricks/python3/lib/python3.9/site-packages (from dbl-tempo<1,>=0.1.2->databricks-feature-store) (1.4.2)
# Requirement already satisfied: scipy in /databricks/python3/lib/python3.9/site-packages (from dbl-tempo<1,>=0.1.2->databricks-feature-store) (1.7.3)
# Requirement already satisfied: ipython in /databricks/python3/lib/python3.9/site-packages (from dbl-tempo<1,>=0.1.2->databricks-feature-store) (8.5.0)
# Requirement already satisfied: click>=5.1 in /databricks/python3/lib/python3.9/site-packages (from flask<3,>=1.1.2->databricks-feature-store) (8.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /databricks/python3/lib/python3.9/site-packages (from flask<3,>=1.1.2->databricks-feature-store) (2.0.1)
# Requirement already satisfied: Jinja2>=2.10.1 in /databricks/python3/lib/python3.9/site-packages (from flask<3,>=1.1.2->databricks-feature-store) (2.11.3)
# Requirement already satisfied: Werkzeug>=0.15 in /databricks/python3/lib/python3.9/site-packages (from flask<3,>=1.1.2->databricks-feature-store) (2.0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /databricks/python3/lib/python3.9/site-packages (from Jinja2>=2.10.1->flask<3,>=1.1.2->databricks-feature-store) (2.0.1)
# Requirement already satisfied: packaging<23 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (21.3)
# Requirement already satisfied: importlib-metadata!=4.7.0,<6,>=3.7.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (4.11.3)
# Requirement already satisfied: gitpython<4,>=2.1.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (3.1.27)
# Requirement already satisfied: cloudpickle<3 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (2.0.0)
# Requirement already satisfied: pytz<2023 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (2021.3)
# Requirement already satisfied: entrypoints<1 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (0.4)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (0.4.2)
# Requirement already satisfied: databricks-cli<1,>=0.8.7 in /databricks/python3/lib/python3.9/site-packages (from mlflow-skinny<3,>=1.28.0->databricks-feature-store) (0.17.4)
# Requirement already satisfied: tabulate>=0.7.7 in /databricks/python3/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (0.8.9)
# Requirement already satisfied: oauthlib>=3.1.0 in /databricks/python3/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (3.2.0)
# Requirement already satisfied: pyjwt>=1.7.0 in /databricks/python3/lib/python3.9/site-packages (from databricks-cli<1,>=0.8.7->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (2.6.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /databricks/python3/lib/python3.9/site-packages (from gitpython<4,>=2.1.0->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (4.0.10)
# Requirement already satisfied: smmap<6,>=3.0.1 in /databricks/python3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython<4,>=2.1.0->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (5.0.0)
# Requirement already satisfied: zipp>=0.5 in /databricks/python3/lib/python3.9/site-packages (from importlib-metadata!=4.7.0,<6,>=3.7.0->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (3.7.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /databricks/python3/lib/python3.9/site-packages (from packaging<23->mlflow-skinny<3,>=1.28.0->databricks-feature-store) (3.0.4)
# Requirement already satisfied: py4j==0.10.9.5 in /local_disk0/.ephemeral_nfs/envs/pythonEnv-b1878b62-c8b4-41f4-8568-c03a661bb9e4/lib/python3.9/site-packages (from pyspark<4,>=3.1.2->databricks-feature-store) (0.10.9.5)
# Requirement already satisfied: idna<4,>=2.5 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.0.0->azure-cosmos<5,>=4.2.0->databricks-feature-store) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.0.0->azure-cosmos<5,>=4.2.0->databricks-feature-store) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /databricks/python3/lib/python3.9/site-packages (from requests>=2.18.4->azure-core<2.0.0,>=1.0.0->azure-cosmos<5,>=4.2.0->databricks-feature-store) (2021.10.8)
# Requirement already satisfied: prompt-toolkit<3.1.0,>3.0.1 in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (3.0.20)
# Requirement already satisfied: pygments>=2.4.0 in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (2.11.2)
# Requirement already satisfied: pexpect>4.3 in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (5.1.1)
# Requirement already satisfied: decorator in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (5.1.1)
# Requirement already satisfied: stack-data in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.2.0)
# Requirement already satisfied: backcall in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.18.1)
# Requirement already satisfied: pickleshare in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.7.5)
# Requirement already satisfied: matplotlib-inline in /databricks/python3/lib/python3.9/site-packages (from ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.1.2)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /databricks/python3/lib/python3.9/site-packages (from jedi>=0.16->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /databricks/python3/lib/python3.9/site-packages (from pexpect>4.3->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.7.0)
# Requirement already satisfied: wcwidth in /databricks/python3/lib/python3.9/site-packages (from prompt-toolkit<3.1.0,>3.0.1->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.2.5)
# Requirement already satisfied: pure-eval in /databricks/python3/lib/python3.9/site-packages (from stack-data->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.2.2)
# Requirement already satisfied: asttokens in /databricks/python3/lib/python3.9/site-packages (from stack-data->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (2.0.5)
# Requirement already satisfied: executing in /databricks/python3/lib/python3.9/site-packages (from stack-data->ipython->dbl-tempo<1,>=0.1.2->databricks-feature-store) (0.8.3)
# Python interpreter will be restarted.

# %% [markdown]
# ####Set the context for the feature store.

# %%
from databricks import feature_store
fs = feature_store.FeatureStoreClient()

# %% [markdown]
# ####Create a feature store table

# %%
fs.drop_table('arl_feature_store.customer_transaction_feature')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File <command-295300276217568>:1
# ----> 1 fs.drop_table('arl_feature_store.customer_transaction_feature')
#
# File /databricks/python/lib/python3.9/site-packages/databricks/feature_store/client.py:338, in FeatureStoreClient.drop_table(self, name)
#     318 """
#     319 Delete the specified feature table. This API also drops the underlying Delta table.
#     320
#    (...)
#     331     published online stores separately.
#     332 """
#     333 name = uc_utils.get_full_table_name(
#     334     name,
#     335     self._spark_client.get_current_catalog(),
#     336     self._spark_client.get_current_database(),
#     337 )
# --> 338 self._compute_client.drop_table(name=name)
#
# File /databricks/python/lib/python3.9/site-packages/databricks/feature_store/_compute_client/_compute_client.py:674, in ComputeClient.drop_table(self, name)
#     668     raise ValueError(
#     669         f"Delta table '{name}' is not a feature table. Use spark API to drop the delta table. "
#     670         f"For more information on Spark API, "
#     671         f"see https://docs.databricks.com/sql/language-manual/sql-ref-syntax-ddl-drop-table.html."
#     672     )
#     673 if not feature_table_exists and not delta_table_exist:
# --> 674     raise ValueError(f"Feature table '{name}' does not exist.")
#     676 feature_table = self._catalog_client.get_feature_table(name, req_context)
#     678 # Delete the feature table and underlying delta table.
#     679 # First perform a dry-run deletion of catalog data as the backend validates the API call.
#
# ValueError: Feature table 'hive_metastore.arl_feature_store.customer_transaction_feature' does not exist.

# %% [markdown]
# ####Create a feature table with 7 day feature

# %%
spark.conf.set("spark.sql.shuffle.partitions", "5")

fs.create_table(
    name="arl_feature_store.customer_transaction_feature",
    primary_keys=["cust_id"],
    df=transacted_amt_feature_credit_7_days,
    description="This table will hold the data of total amount transacted by customer for give timerange"
)
# Out:
# 2023/02/01 13:31:08 INFO databricks.feature_store._compute_client._compute_client: Created feature table 'hive_metastore.arl_feature_store.customer_transaction_feature'.
# /databricks/python/lib/python3.9/site-packages/databricks/feature_store/entities/_feature_store_object.py:8: FutureWarning: ``databricks.feature_store.entities.feature_table.FeatureTable.keys`` is deprecated since v0.3.6. This method will be removed in a future release. Use ``FeatureTable.primary_keys`` instead.
#   yield prop, self.__getattribute__(prop)
# Out[14]: <FeatureTable: keys=['cust_id'], tags={}>

# %% [markdown]
# #### Merge the feature table with 30 days feature data.

# %%
fs.write_table(
  name = "arl_feature_store.customer_transaction_feature",
  df = transacted_amt_feature_credit_30_days,
  mode = "merge")

# %% [markdown]
# ####Merge the feature table with 60 days feature data.

# %%
fs.write_table(
  name = "arl_feature_store.customer_transaction_feature",
  df = transacted_amt_feature_credit_60_days,
  mode = "merge")

# %% [markdown]
# ####Check if data is stored in feature store table

# %%
# %sql
select 
todays_date, 
cust_id,
amount_transacted_by_cust_over_7_days_credit,
total_no_of_credit_transactions_7_days,
amount_transacted_by_cust_over_30_days_credit,
total_no_of_credit_transactions_30_days,
amount_transacted_by_cust_over_60_days_credit,
total_no_of_credit_transactions_60_days
from arl_feature_store.customer_transaction_feature;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>todays_date</th><th>cust_id</th><th>amount_transacted_by_cust_over_7_days_credit</th><th>total_no_of_credit_transactions_7_days</th><th>amount_transacted_by_cust_over_30_days_credit</th><th>total_no_of_credit_transactions_30_days</th><th>amount_transacted_by_cust_over_60_days_credit</th><th>total_no_of_credit_transactions_60_days</th></tr></thead><tbody><tr><td>2023-02-01</td><td>CUST235925</td><td>35028.0</td><td>1</td><td>35028.0</td><td>1</td><td>122209.0</td><td>2</td></tr><tr><td>2023-02-01</td><td>CUST301488</td><td>null</td><td>null</td><td>null</td><td>null</td><td>54401.0</td><td>1</td></tr><tr><td>2023-02-01</td><td>CUST854589</td><td>21406.0</td><td>1</td><td>90951.0</td><td>3</td><td>90951.0</td><td>3</td></tr></tbody></table></div>

# %%
# %sql
describe  arl_feature_store.customer_transaction_feature;
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>col_name</th><th>data_type</th><th>comment</th></tr></thead><tbody><tr><td>cust_id</td><td>string</td><td>null</td></tr><tr><td>amount_transacted_by_cust_over_7_days_credit</td><td>float</td><td>null</td></tr><tr><td>total_no_of_credit_transactions_7_days</td><td>int</td><td>null</td></tr><tr><td>todays_date</td><td>date</td><td>null</td></tr><tr><td>amount_transacted_by_cust_over_30_days_credit</td><td>float</td><td>null</td></tr><tr><td>total_no_of_credit_transactions_30_days</td><td>int</td><td>null</td></tr><tr><td>amount_transacted_by_cust_over_60_days_credit</td><td>float</td><td>null</td></tr><tr><td>total_no_of_credit_transactions_60_days</td><td>int</td><td>null</td></tr></tbody></table></div>
